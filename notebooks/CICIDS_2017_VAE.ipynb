# %%
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import sys

sys.path.append('../')

# %%
from src.data import create_dataset, clean_dataset
from src.utils import *

# %%
np.random.seed(17)

# %% [markdown]
# Dataset [CICIDS 2017](https://www.kaggle.com/datasets/cicdataset/cicids2017)

# %%
# %%time

data_path = '/home/churilov/data/other/Mephi/CICIDS_2017/MachineLearningCSV/MachineLearningCVE'
df = create_dataset(data_path=data_path)
# Out:
# found 8 files
# number Na in df: 1358
# CPU times: user 18.5 s, sys: 4.37 s, total: 22.9 s
# Wall time: 22.8 s

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2829385 entries, 0 to 2830742
# Data columns (total 81 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0    Destination Port             int64
#  1    Flow Duration                int64
#  2    Total Fwd Packets            int64
#  3    Total Backward Packets       int64
#  4   Total Length of Fwd Packets   int64
#  5    Total Length of Bwd Packets  int64
#  6    Fwd Packet Length Max        int64
#  7    Fwd Packet Length Min        int64
#  8    Fwd Packet Length Mean       float64
#  9    Fwd Packet Length Std        float64
#  10  Bwd Packet Length Max         int64
#  11   Bwd Packet Length Min        int64
#  12   Bwd Packet Length Mean       float64
#  13   Bwd Packet Length Std        float64
#  14  Flow Bytes/s                  float64
#  15   Flow Packets/s               float64
#  16   Flow IAT Mean                float64
#  17   Flow IAT Std                 float64
# ...

# %%
df.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count       2.829385e+06    2.829385e+06        2.829385e+06
# mean        8.071249e+03    1.479276e+07        9.364763e+00
# std         1.828343e+04    3.366026e+07        7.498527e+02
# min         0.000000e+00   -1.300000e+01        1.000000e+00
# 25%         5.300000e+01    1.550000e+02        2.000000e+00
# 50%         8.000000e+01    3.132700e+04        2.000000e+00
# 75%         4.430000e+02    3.221416e+06        5.000000e+00
# max         6.553500e+04    1.200000e+08        2.197590e+05
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count             2.829385e+06                 2.829385e+06
# mean              1.039869e+01                 5.495661e+02
# std               9.976276e+02                 9.995980e+03
# min               0.000000e+00                 0.000000e+00
# 25%               1.000000e+00                 1.200000e+01
# ...

# %%
df.shape
# Out:
# (2829385, 81)

# %%
# %%time

df = clean_dataset(df)
# Out:
# CPU times: user 3.63 s, sys: 2.21 s, total: 5.84 s
# Wall time: 5.83 s

# %%
df.sample(5)
# Out:
#           Destination Port   Flow Duration   Total Fwd Packets  \
# 1769043                 53           69464                   1
# 2181015              45221              80                   1
# 444807                2038              48                   1
# 478587                1096              54                   1
# 1464355                443       115227321                  26
#
#           Total Backward Packets  Total Length of Fwd Packets  \
# 1769043                        1                           39
# 2181015                        1                            0
# 444807                         1                            0
# 478587                         1                            2
# 1464355                       19                         3183
#
#           Total Length of Bwd Packets   Fwd Packet Length Max  \
# 1769043                           249                      39
# 2181015                             0                       0
# ...

# %%
label_cols = [c for c in df.columns if 'Label' in c]
label_cols
# Out:
# ['Label_bin', 'Label_encoded', 'Label_str']

# %%
X, y = df.drop(label_cols, axis=1), df['Label_bin']

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
for c in df.columns:
    print(c.strip())
# Out:
# Destination Port
# Flow Duration
# Total Fwd Packets
# Total Backward Packets
# Total Length of Fwd Packets
# Total Length of Bwd Packets
# Fwd Packet Length Max
# Fwd Packet Length Min
# Fwd Packet Length Mean
# Fwd Packet Length Std
# Bwd Packet Length Max
# Bwd Packet Length Min
# Bwd Packet Length Mean
# Bwd Packet Length Std
# Flow Bytes/s
# Flow Packets/s
# Flow IAT Mean
# Flow IAT Std
# Flow IAT Max
# Flow IAT Min
# Fwd IAT Total
# Fwd IAT Mean
# Fwd IAT Std
# Fwd IAT Max
# Fwd IAT Min
# Bwd IAT Total
# Bwd IAT Mean
# Bwd IAT Std
# Bwd IAT Max
# Bwd IAT Min
# Fwd PSH Flags
# Bwd PSH Flags
# Fwd URG Flags
# Bwd URG Flags
# Fwd Header Length
# Bwd Header Length
# Fwd Packets/s
# Bwd Packets/s
# Min Packet Length
# Max Packet Length
# Packet Length Mean
# Packet Length Std
# Packet Length Variance
# FIN Flag Count
# SYN Flag Count
# RST Flag Count
# PSH Flag Count
# ACK Flag Count
# URG Flag Count
# CWE Flag Count
# ECE Flag Count
# Down/Up Ratio
# Average Packet Size
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=17)

# %%
# encoder training on clean samples only

X_train_clean, y_train_clean = X_train[y_train!=1], y_train[y_train!=1]

# %%
X_train_clean, X_val_clean, y_train_clean, y_val_clean = train_test_split(
    X_train_clean, y_train_clean, test_size=0.2, random_state=17)

# %%
from tqdm import tqdm

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch import optim 

from torchvision import transforms

# %%
class CICIDSDataset(Dataset):
    def __init__(self, dataframe):
        self.dataframe = dataframe

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, index):
        # return self.dataframe.iloc[index].values
        return self.dataframe[index]

# %%
from torch.utils.data import Dataset

# %%
train_loader = torch.utils.data.DataLoader(CICIDSDataset(X_train_clean), batch_size=4, drop_last=True)
val_loader = torch.utils.data.DataLoader(CICIDSDataset(X_val_clean), batch_size=4)

# %%
latent_features = 8

class LinearVAE(nn.Module):
    def __init__(self):
        super(LinearVAE, self).__init__()
 
        # encoder
        self.enc_bn = nn.BatchNorm1d(32)
        self.enc1 = nn.Linear(in_features=78, out_features=32)
        self.enc2 = nn.Linear(in_features=32, out_features=latent_features*2)
 
        # decoder 
        self.dec_bn = nn.BatchNorm1d(32)
        self.dec1 = nn.Linear(in_features=latent_features, out_features=32)
        self.dec2 = nn.Linear(in_features=32, out_features=78)
        
    def reparameterize(self, mu, log_var):
        """
        :param mu: mean from the encoder's latent space
        :param log_var: log variance from the encoder's latent space
        """
        std = torch.exp(0.5*log_var) # standard deviation
        eps = torch.randn_like(std) # `randn_like` as we need the same size
        sample = mu + (eps * std) # sampling as if coming from the input space
        return sample
 
    def forward(self, x):
        # encoding
        x = F.relu(self.enc1(x))
        x = self.enc_bn(x)
        x = self.enc2(x).view(-1, 2, latent_features)
        # get `mu` and `log_var`
        mu = x[:, 0, :] # the first feature values as mean
        log_var = x[:, 1, :] # the other feature values as variance
        # get the latent vector through reparameterization
        z = self.reparameterize(mu, log_var)
 
        # decoding
        x = F.relu(self.dec1(z))
        x = self.dec_bn(x)
        reconstruction = torch.sigmoid(self.dec2(x))
        return reconstruction, mu, log_var

# %%
def final_loss(criterion, mu, logvar):
    """
    This function will add the reconstruction loss (BCELoss) and the 
    KL-Divergence.
    KL-Divergence = 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    :param bce_loss: recontruction loss
    :param mu: the mean from the latent vector
    :param logvar: log variance from the latent vector
    """
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    # print(f"losses criterion:{np.around(criterion.detach().cpu().numpy(), decimals=3)} KLD:{np.around(KLD.detach().cpu().numpy(), decimals=3)}")
    return criterion + KLD

# %%
# leanring parameters
# epochs = 2
epochs = 1
batch_size = 64
lr = 0.001
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
model = LinearVAE().to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)
# criterion = nn.BCELoss(reduction='mean')
criterion = nn.MSELoss().to(device)

# %%
data_batch = next(iter(train_loader)).to(device)

# %%
reconstruction, mu, logvar = model(data_batch.float())

# %%
loss = criterion(reconstruction, data_batch.float())
loss.item()
# Out:
# 0.2632978856563568

# %%
# inp = torch.randn(3, requires_grad=True)
# target = torch.empty(3).random_(2)
# criterion(inp, target)
# inp, target

# %%
len(train_loader)
# Out:
# 363476

# %%
# нужно сомтреть графики лоссов не по всем объектам, а по эпохам

# %%
900%100
# Out:
# 0

# %%
# %%time

train_loss = []
train_epoch_loss = []
val_epoch_loss = []

for epoch in range(epochs):
    print(f"Epoch {epoch+1} of {epochs}")
    model.train()
    running_loss = 0.0
    for i, data in enumerate(tqdm(train_loader)):
        # data, _ = data
        data = data.to(device)
        # data = data.view(data.size(0), -1)
#         print(f'{i}) size: {data.size()}')
        optimizer.zero_grad()
        reconstruction, mu, logvar = model(data.float())
        loss_ = criterion(reconstruction, data.float())
        loss = final_loss(loss_, mu, logvar)
        running_loss += loss.item()
        loss.backward()
        optimizer.step()
        train_loss.append(loss.item())
    
        if i % 100 == 0:
            print(f'mean epoch loss: {running_loss/len(train_loader)}')
            train_epoch_loss.append(running_loss/len(train_loader))
    
    model.eval()
    running_loss = 0.0
    with torch.no_grad():
        for i, data in enumerate(tqdm(val_loader)):
            # data, _ = data
            data = data.to(device)
            # data = data.view(data.size(0), -1)
            reconstruction, mu, logvar = model(data.float())
            loss_ = criterion(reconstruction, data.float())
            loss = final_loss(loss_, mu, logvar)
            running_loss += loss.item()
            # val_loss.append(loss.item())
    
    val_epoch_loss.append(running_loss/len(val_loader))
    
#     print(f"Train Loss: {train_epoch_loss:.4f}")
#     print(f"Val Loss: {val_epoch_loss:.4f}")
# Out:
# Epoch 1 of 1
#   0%|          | 12/363476 [00:00<52:22, 115.67it/s]
# mean epoch loss: 2.1510058140229683e-05
#   0%|          | 113/363476 [00:01<57:32, 105.26it/s]
# mean epoch loss: 0.0005862187381363688
#   0%|          | 212/363476 [00:01<52:54, 114.44it/s]
# mean epoch loss: 0.0007617001511357195
#   0%|          | 321/363476 [00:02<56:38, 106.85it/s]
# mean epoch loss: 0.0008563371438644865
#   0%|          | 415/363476 [00:03<53:47, 112.51it/s]
# mean epoch loss: 0.0009075741087254163
#   0%|          | 516/363476 [00:04<59:33, 101.58it/s]
# mean epoch loss: 0.0009479695623768944
#   0%|          | 624/363476 [00:05<53:14, 113.59it/s]
# mean epoch loss: 0.0009797490438080245
#   0%|          | 717/363476 [00:06<54:59, 109.94it/s]
# mean epoch loss: 0.0010079006566125377
#   0%|          | 815/363476 [00:07<53:43, 112.51it/s]
# mean epoch loss: 0.0010276871682885658
#   0%|          | 919/363476 [00:08<57:17, 105.48it/s]
# mean epoch loss: 0.0010511357921243682
# ...

# %%
train_loss = []
train_epoch_loss = []
val_epoch_loss = []

for epoch in range(epochs):
    print(f"Epoch {epoch+1} of {epochs}")
    model.train()
    running_loss = 0.0
    for i, data in enumerate(tqdm(train_loader)):
        # data, _ = data
        data = data.to(device)
        # data = data.view(data.size(0), -1)
#         print(f'{i}) size: {data.size()}')
        optimizer.zero_grad()
        reconstruction, mu, logvar = model(data.float())
        loss_ = criterion(reconstruction, data.float())
        loss = final_loss(loss_, mu, logvar)
        running_loss += loss.item()
        loss.backward()
        optimizer.step()
        train_loss.append(loss.item())
    
    print(f'mean epoch loss: {running_loss/len(train_loader)}')
    train_epoch_loss.append(running_loss/len(train_loader))
    
    model.eval()
    running_loss = 0.0
    with torch.no_grad():
        for i, data in enumerate(tqdm(val_loader)):
            # data, _ = data
            data = data.to(device)
            # data = data.view(data.size(0), -1)
            reconstruction, mu, logvar = model(data.float())
            loss_ = criterion(reconstruction, data.float())
            loss = final_loss(loss_, mu, logvar)
            running_loss += loss.item()
            # val_loss.append(loss.item())
    
    val_epoch_loss.append(running_loss/len(val_loader))
    
#     print(f"Train Loss: {train_epoch_loss:.4f}")
#     print(f"Val Loss: {val_epoch_loss:.4f}")

# %%
val_epoch_loss
# Out:
# [0.014391223584375357]

# %%
pd.Series(train_loss).rolling(window=3).mean().dropna().values[:30]
# Out:
# array([7.26506821, 6.07471673, 6.46762005, 5.6306874 , 6.03148572,
#        4.76070452, 4.85262839, 4.64176321, 5.17982372, 5.42515691,
#        5.56143443, 4.62757754, 3.61028918, 2.98397867, 3.25324631,
#        3.35091805, 2.90151767, 2.43333725, 2.29436608, 2.90169779,
#        2.825207  , 2.64103333, 1.88564269, 1.64120762, 2.08384275,
#        2.37669587, 2.51785413, 2.18545874, 1.95182343, 1.96474381])

# %%
pd.Series(train_loss).rolling(window=3).mean().dropna().values
# Out:
# array([7.26506821e+00, 6.07471673e+00, 6.46762005e+00, ...,
#        1.23678708e-02, 7.23501404e-03, 6.41024004e-03])

# %%
window_size=300

# plt.plot(pd.Series(train_loss).values, color='b', label='train')
plt.plot(pd.Series(train_loss).rolling(window=window_size).mean().dropna().values, color='y', label='loss')
plt.title('train_loss')
plt.legend()
plt.show()

# %% [markdown]
# Классификация энкодером

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
test_loader = torch.utils.data.DataLoader(CICIDSDataset(X_test), batch_size=1)

# %%
# getting the MSE btw data and reconstruction for normal objects

model.eval()
losses = []
with torch.no_grad():
    for i, data in enumerate(tqdm(test_loader)):
        data = data.to(device)
        reconstruction, mu, logvar = model(data.float())
        loss = criterion(reconstruction, data.float())
        losses.append(loss.item())
# Out:
# 100%|██████████| 565576/565576 [11:47<00:00, 799.69it/s]

# %%
from scipy.stats import describe
describe(losses)
# Out:
# DescribeResult(nobs=565576, minmax=(0.002490266924723983, 0.19222362339496613), mean=0.017854730030141135, variance=0.00044176630630396376, skewness=2.3359702978790815, kurtosis=6.47127252299712)

# %%
print_corves(losses, y_test)

# %%
print_optimal_threshold(losses, y_test)
# Out:
# Best threshold by Youden’s J statistic: 0.008
# Best threshold by optimising F-score: 0.008, F-Score=0.46

# %%
# threshold=0.0139
threshold = 0.025

# %%
# X_bot = X[y==1]
# X_bot_scaled = scaler.transform(X_bot)
# X_bot_loader = torch.utils.data.DataLoader(CICIDSDataset(X_bot_scaled), batch_size=1)

# %%
net_pred = np.array(losses.copy())
net_pred[net_pred>=threshold] = 1
net_pred[net_pred< threshold] = 0

# %%
print('VAE:\n', classification_report(y_test, net_pred))
# Out:
# VAE:
#                precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83    453939
#            1       0.34      0.36      0.35    111637
#
#     accuracy                           0.73    565576
#    macro avg       0.59      0.59      0.59    565576
# weighted avg       0.74      0.73      0.74    565576

# %%
plot_confusion_matrix(y_test, net_pred)

# %%
# %%time

logreg = LogisticRegression(solver='liblinear').fit(X_train, y_train)

# %%
pred = logreg.predict(X_test)
print('logreg:\n', classification_report(y_test, pred))

# %%
pred_proba = logreg.predict_proba(X_test)
# keep probabilities for the positive outcome only
pred_proba = pred_proba[:, 1]
print_corves(pred_proba, y_test)

# %%
model = logreg
pred_proba = model.predict_proba(X_test)
pred_proba = pred_proba[:, 1]

optimal_threshold(pred_proba, y_test)

# %%
threshold = 0.009

pred_proba[pred_proba>=threshold] = 1
pred_proba[pred_proba< threshold] = 0

print(f'logreg (threshold={threshold}):\n', classification_report(y_test, pred_proba))

# %%
plot_confusion_matrix(y_test, pred_proba)
